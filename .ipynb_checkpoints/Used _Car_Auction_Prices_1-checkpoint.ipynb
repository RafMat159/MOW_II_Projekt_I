# %% [markdown]
# ## Pierwsza część projektu

# %% [markdown]
# Zbiór danych zawiera historyczne ceny sprzedaży samochodów na aukcjach, zebrane z zewnętrznych źródeł internetowych. Został zebrany w 2015 roku.
#
# Zbiór danych zawiera następujące kolumny:
# - year - rok produkcji pojazdu;
# - make - marka pojazdu (np. Toyota, Ford);
# - model - model pojazdu (np. Corolla, Mustang);
# - trim - wersja wyposażenia pojazdu (np. SE, Base);
# - body - rodzaj nadwozia pojazdu (np. sedan, SUV);
# - transmission - rodzaj skrzyni biegów (np. automatyczna, manualna);
# - vin - numer identyfikacyjny pojazdu (VIN);
# - state - stan (lokalizacja geograficzna) w USA, gdzie odbyła się sprzedaż;
# - condition - stan pojazdu oceniany w skali od 1 do 5, gdzie wyższe wartości oznaczają lepszy stan techniczny (zmienna ciągła);
# - odometer - przebieg pojazdu w milach;
# - color - kolor karoserii pojazdu;
# - interior - kolor wnętrza pojazdu;
# - seller - nazwa lub identyfikator sprzedającego pojazd;
# - mmr - wartość pojazdu według Manheim Market Report (MMR), używana jako wskaźnik wartości rynkowej;
# - sellingprice - rzeczywista cena sprzedaży pojazdu na aukcji;
# - saledate - data sprzedaży pojazdu.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from vininfo import Vin

# %%
df = pd.read_csv('car_prices.csv', on_bad_lines='skip')
df.head(2)
# Out:
#    year make    model trim body transmission                vin state  \
# 0  2015  Kia  Sorento   LX  SUV    automatic  5xyktca69fg566472    ca
# 1  2015  Kia  Sorento   LX  SUV    automatic  5xyktca69fg561319    ca
#
#    condition  odometer  color interior                   seller    mmr  \
# 0        5.0   16639.0  white    black  kia motors america, inc  20500
# 1        5.0    9393.0  white    beige  kia motors america, inc  20800
#
#    sellingprice                                 saledate
# 0         21500  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1         21500  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)

# %%
df.shape
# Out:
# (558811, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558811 entries, 0 to 558810
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558811 non-null  int64
#  1   make          548510 non-null  object
#  2   model         548412 non-null  object
#  3   trim          548160 non-null  object
#  4   body          545616 non-null  object
#  5   transmission  493458 non-null  object
#  6   vin           558811 non-null  object
#  7   state         558811 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558717 non-null  float64
#  10  color         558062 non-null  object
#  11  interior      558062 non-null  object
#  12  seller        558811 non-null  object
#  13  mmr           558811 non-null  int64
#  14  sellingprice  558811 non-null  int64
#  15  saledate      558811 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 68.2+ MB

# %%
missing_values = df.isnull().sum()
print(missing_values)

missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65353
# vin                 0
# state               0
# condition       11794
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                 0
# sellingprice        0
# saledate            0
# dtype: int64
# year             0.000000
# make             1.843378
# model            1.860915
# trim             1.906011
# body             2.361263
# transmission    11.695010
# vin              0.000000
# state            0.000000
# condition        2.110553
# odometer         0.016821
# color            0.134035
# interior         0.134035
# seller           0.000000
# mmr              0.000000
# sellingprice     0.000000
# saledate         0.000000
# dtype: float64

# %%
missing_percentage_2 = missing_percentage[missing_percentage > 0]
plt.figure(figsize=(10, 6))
missing_percentage_2.plot(kind='bar', color='skyblue')
plt.title('Procent brakujących wartości w kolumnach [%]')
plt.xlabel('Nazwy kolumn')
plt.ylabel('Liczba brakujących wartości')
plt.xticks(rotation=45)  # Obrót etykiet na osi X
plt.tight_layout()  # Dostosowuje układ, aby etykiety nie były obcięte
plt.savefig('brakujace.png', dpi=300, facecolor='white')
plt.show()

# %%
nums = df.select_dtypes(exclude=['object'])
nums.describe(percentiles=(.25, .75, .90, .95, .98))
# Out:
#                 year      condition       odometer            mmr  \
# count  558811.000000  547017.000000  558717.000000  558811.000000
# mean     2010.038696       3.424512   68323.195797   13769.324646
# std         3.966812       0.949439   53397.752933    9679.874607
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000       2.700000   28374.000000    7100.000000
# 50%      2012.000000       3.600000   52256.000000   12250.000000
# 75%      2013.000000       4.200000   99112.000000   18300.000000
# 90%      2014.000000       4.600000  142760.400000   25500.000000
# 95%      2014.000000       4.800000  170059.000000   30600.000000
# 98%      2014.000000       5.000000  202596.680000   38500.000000
# max      2015.000000       5.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558811.000000
# mean    13611.262461
# std      9749.656919
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# 90%     25500.000000
# 95%     30600.000000
# 98%     38500.000000
# max    230000.000000

# %%
nums.hist(bins=30, figsize=(15, 10), layout=(3, 2))
plt.tight_layout()
plt.savefig('histogramy.png', dpi=300, facecolor='white')
plt.show()

# %% [markdown]
# Można spróbować wykonać przekształcenie logarytmiczne żeby te histogramy nie rozciągały się tak w prawo - szczególnie widoczne na zmiennych sellingprice, mmr, odometer

# %%
import numpy as np
import matplotlib.pyplot as plt

# Tworzenie histogramów na przekształconych logarytmicznie danych, ale tylko do wizualizacji
nums_log = nums.copy()
nums_log[["odometer","mmr","sellingprice"]]=np.log(nums_log[["odometer","mmr","sellingprice"]])

nums_log.hist(bins=30, figsize=(15, 10), layout=(3, 2))
plt.tight_layout()
plt.savefig('histogramy_log.png', dpi=300, facecolor='white')
plt.show()

# %%
non_nums = df.select_dtypes(include=['object'])
non_nums.describe()
# Out:
#           make   model    trim    body transmission                vin  \
# count   548510  548412  548160  545616       493458             558811
# unique      96     973    1975      86            2             550296
# top       Ford  Altima    Base   Sedan    automatic  wbanv13588cz57827
# freq     93554   19349   55817  199437       475914                  5
#
#          state   color interior              seller  \
# count   558811  558062   558062              558811
# unique      38      20       17               14264
# top         fl   black    black  nissan-infiniti lt
# freq     82945  110970   244325               19693
#
#                                        saledate
# count                                    558811
# unique                                     3745
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5334

# %%
import seaborn as sns

def show_boxplot(data, title):
    plt.figure(figsize=(15, 10))
    sns.boxplot(data=data)
    plt.title(title)
    plt.grid()
    plt.savefig('boxplot_wszystko.png', dpi=300, facecolor='white')
    plt.show()

# %%
show_boxplot(nums, 'Boxploty dla zmiennych numerycznych')

# %% [markdown]
# Na powyższym wykresie przedstawiono boxploty dla zmiennych numerycznych, jednak ze względu na dużą różnicę w wartościach pomiędzy zmiennymi, szczegóły niektórych cech są trudne do dostrzeżenia. Aby lepiej zobrazować rozkład wartości, w tym wartości odstające, zostaną przedstawione oddzielne boxploty dla każdej z cech numerycznych. Dodatkowo, wykresy te zostaną wygenerowane zarówno z uwzględnieniem danych odstających, jak i bez nich, aby zapewnić pełniejszą analizę danych.

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
num_columns = ['sellingprice', 'odometer', 'mmr', 'year', 'condition']

# Usuwanie wartości odstających dla każdej zmiennej numerycznej
nums_clean = nums.copy()
for column in num_columns:
    nums_clean = remove_outliers(nums_clean, column)

# %%
def show_separate_boxplot(data,data_clean,num_columns):
    for column in num_columns:    
        fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    
        sns.boxplot(y=data[column], ax=axes[0])
        axes[0].set_title(f'Boxplot dla cechy: {column} (przed usunięciem wartości odstających)')
    
        sns.boxplot(y=data_clean[column], ax=axes[1])
        axes[1].set_title(f'Boxplot dla cechy: {column} (po usunięciu wartości odstających)')
    
        plt.tight_layout()
        plt.savefig(f'boxplot_{column}.png', dpi=300, facecolor='white')
        plt.show()

# %%
show_separate_boxplot(nums,nums_clean,num_columns)

# %% [markdown]
# Wartości odstające mają największy wpływ na zmienne takie jak cena sprzedaży (sellingprice), przebieg (odometer) i wartość rynkowa (mmr), które charakteryzują się nielicznymi, ale bardzo skrajnymi wartościami odstającymi. Po ich usunięciu uzyskujemy bardziej klarowny obraz typowego rozkładu danych, co pozwala lepiej zrozumieć, jakie są rzeczywiste wartości dominujące w zbiorze danych.
#
# W przypadku zmiennych rok produkcji (year) i stan techniczny (condition), wartości odstające mają mniejszy wpływ. Boxplot dla stanu technicznego jest bardzo jednorodny, co wskazuje, że ta zmienna nie zawiera wielu ekstremalnych wartości, a typowy stan techniczny pojazdów waha się od 2.5 do 4.5.

# %%
sns.pairplot(nums)
plt.suptitle('Pairplot dla wybranych zmiennych numerycznych', y=1.02)
plt.savefig('pairplot.png', dpi=300, facecolor='white')
plt.show()

# %% [markdown]
# Patrząc na pairplot, widzimy wyraźne zależności między niektórymi zmiennymi (np. cena sprzedaży a rok produkcji, przebieg czy wartość rynkowa). Aby lepiej zrozumieć, jak silne są te zależności, warto obliczyć współczynniki korelacji dla tych zmiennych. Pozwoli to na dokładniejszą ocenę siły tych relacji.

# %%
nums_corr = nums.corr()
f, ax = plt.subplots(figsize=(16, 16))

sns.heatmap(nums_corr, annot=True, fmt='.2f', ax=ax)
plt.savefig('korelacja.png', dpi=300, facecolor='white')
plt.show()

# %% [markdown]
# Rok produkcji (year) ma silną dodatnią korelację z ceną sprzedaży (0.59), co oznacza, że nowsze samochody zazwyczaj sprzedają się za wyższą cenę.
# Stan techniczny (condition) ma dodatnią korelację z ceną sprzedaży (0.54), co sugeruje, że samochody w lepszym stanie są droższe.
# Przebieg (odometer) wykazuje silną ujemną korelację z ceną sprzedaży (-0.58), co oznacza, że większy przebieg zmniejsza wartość samochodu.
# MMR (wartość rynkowa) ma bardzo silną dodatnią korelację z ceną sprzedaży (0.98), co wskazuje, że wartość rynkowa samochodu dobrze prognozuje jego cenę na aukcji.

# %%
df_sample = df.sample(n=1000, random_state=42)

plt.figure(figsize=(12, 6))
sns.scatterplot(x='sellingprice', y='odometer', 
                hue='condition', 
                data=df_sample, palette='viridis', sizes=(20, 200), alpha=0.9)

plt.title('Wykres sprzedaży samochodów - Cena, Przebieg i Stan pojazdu dla 1000 losowych próbek')
plt.xlabel('Cena sprzedaży (sellingprice)')
plt.ylabel('Przebieg (odometer)')
plt.legend(title='Stan pojazdu')
plt.savefig("sprzedaz_samochodow.png", dpi=300, facecolor='white')
plt.show()

# %% [markdown]
# Na powyższym wykresie zbadano zależność między przebiegiem pojazdów a ceną sprzedaży, uwzględniając jednocześnie ich stan techniczny. Zauważalna jest silna ujemna zależność – samochody z większym przebiegiem są zazwyczaj tańsze. Lepszy stan techniczny pojazdu wpływa pozytywnie na cenę sprzedaży, co pozwala niektórym pojazdom osiągnąć wyższe ceny, nawet przy relatywnie dużym przebiegu. Najwyższe ceny uzyskują samochody w najlepszym stanie, podczas gdy pojazdy w najgorszym stanie sprzedają się za niższe kwoty, niezależnie od przebiegu.

# %%
df_sample = df.sample(n=1000, random_state=42)

plt.figure(figsize=(12, 6))
sns.scatterplot(x='sellingprice', y='year', 
                hue='odometer', 
                data=df_sample, palette='viridis', sizes=(20, 200), alpha=0.9)

plt.title('Wykres sprzedaży samochodów - Cena, Przebieg i Rok produkcji pojazdu dla 1000 losowych próbek')
plt.xlabel('Cena sprzedaży (sellingprice)')
plt.ylabel('Rok produkcji pojazdu (year)')
plt.legend(title='Przebieg pojazdu (odemeter)')
plt.savefig('sprzedaz_samochodow_cena_przebieg_rok.png', dpi=300, facecolor='white')
plt.show()

# %% [markdown]
# Wykres przedstawia zależność między rokiem produkcji a ceną sprzedaży samochodów, uwzględniając jednocześnie ich przebieg. Zauważalna jest wyraźna tendencja – nowsze samochody (z lat 2010–2015) osiągają wyższe ceny, podczas gdy starsze pojazdy (sprzed 2005 roku) sprzedają się za znacznie niższe kwoty. Przebieg również ma istotny wpływ – samochody z mniejszym przebiegiem mają tendencję do wyższych cen, zwłaszcza w przypadku nowszych roczników. Samochody z większym przebiegiem, niezależnie od roku produkcji, zazwyczaj mają niższą wartość.

# %%
sales_by_state = df['state'].value_counts()
print("Liczba sprzedanych pojazdów w poszczególnych stanach:")
print(sales_by_state)

plt.figure(figsize=(12, 6))
sales_by_state.plot(kind='bar', color='skyblue')
plt.title('Liczba sprzedanych pojazdów w poszczególnych stanach USA')
plt.xlabel('Stan')
plt.ylabel('Liczba sprzedanych pojazdów')
plt.savefig('liczba_sprzedanych_pojazdow_w_poszcegolnych_stanach.png', dpi=300, facecolor='white')
plt.show()
# Out:
# Liczba sprzedanych pojazdów w poszczególnych stanach:
# fl    82945
# ca    73148
# pa    53907
# tx    45913
# ga    34750
# nj    27784
# il    23486
# nc    21845
# oh    21575
# tn    20895
# mo    16013
# mi    15511
# nv    12685
# va    12027
# md    11158
# wi     9851
# mn     9429
# az     8741
# co     7775
# wa     7416
# ma     6729
# ny     5699
# in     4325
# sc     4251
# ne     4013
# on     3442
# pr     2725
# la     2191
# ms     1851
# ut     1836
# qc     1245
# hi     1237
# or     1155
# ab      928
# nm      171
# ok       72
# ns       61
# al       26
# Name: state, dtype: int64

# %% [markdown]
#  Największą liczbę sprzedanych pojazdów odnotowano w stanach Floryda (FL) oraz Kalifornia (CA). Te dwa stany zdecydowanie wyróżnią się jako liderzy. W czołówce są także Teksas (TX), Pensylwania (PA) oraz Georgia (GA).

# %%
sales_by_make = df.groupby('make')['sellingprice'].count().sort_values(ascending=False).head(10)
print("Top 10 najczęściej sprzedawanych marek samochodów:")
print(sales_by_make)

plt.figure(figsize=(12, 6))
sales_by_make.plot(kind='bar', color='lightgreen')
plt.title('Top 10 najczęściej sprzedawanych marek samochodów')
plt.xlabel('Marka')
plt.ylabel('Liczba sprzedanych pojazdów')
plt.savefig('liczba_sprzedanych_pojazdow_marka.png', dpi=300, facecolor='white')
plt.show()
# Out:
# Top 10 najczęściej sprzedawanych marek samochodów:
# make
# Ford         93554
# Chevrolet    60197
# Nissan       53946
# Toyota       39871
# Dodge        30710
# Honda        27206
# Hyundai      21816
# BMW          20719
# Kia          18077
# Chrysler     17276
# Name: sellingprice, dtype: int64

# %% [markdown]
# Ford zdecydowanie dominuje jako najczęściej sprzedawana marka, z wyraźną przewagą nad Chevroletem oraz Nissanem. Toyota oraz Dodge zamykają czołową piątkę. Wynik ten może odzwierciedlać popularność tych marek na rynku amerykańskim, gdzie dominują pojazdy amerykańskie i azjatyckie

# %%
sales_by_year = df['year'].value_counts().sort_index()
print("Liczba sprzedanych pojazdów w poszczególnych latach produkcji:")
print(sales_by_year)

plt.figure(figsize=(12, 6))
sales_by_year.plot(kind='bar', color='orange')
plt.title('Liczba sprzedanych pojazdów według roku produkcji')
plt.xlabel('Rok produkcji')
plt.ylabel('Liczba sprzedanych pojazdów')
plt.savefig("liczba_sprzedanych_pojazdow_rok.png", dpi=300, facecolor='white')
plt.show()
# Out:
# Liczba sprzedanych pojazdów w poszczególnych latach produkcji:
# 1982         2
# 1983         1
# 1984         5
# 1985        10
# 1986        11
# 1987         8
# 1988        11
# 1989        20
# 1990        49
# 1991        67
# 1992       132
# 1993       205
# 1994       392
# 1995       711
# 1996       851
# 1997      1546
# 1998      2149
# 1999      3363
# 2000      5227
# 2001      6468
# 2002      9715
# 2003     13281
# 2004     17342
# 2005     21394
# 2006     26913
# 2007     30845
# 2008     31502
# 2009     20594
# 2010     26485
# 2011     48548
# 2012    102315
# 2013     98168
# 2014     81070
# 2015      9411
# Name: year, dtype: int64

# %% [markdown]
# Największa liczba sprzedanych pojazdów pochodzi z lat 2011-2014, co sugeruje, że rynek używanych samochodów obejmuje głównie nowsze modele, które mają jeszcze sporo lat eksploatacji przed sobą. Starsze roczniki, szczególnie te sprzed 2000 roku, są rzadziej spotykane, co jest zgodne z trendem zmniejszania się podaży starszych aut.

# %%
sales_by_body = df.groupby('body')['sellingprice'].count().sort_values(ascending=False).head(10)
print("Top 10 najlepiej sprzedających się typów nadwozia:")
print(sales_by_body)

plt.figure(figsize=(12, 6))
sales_by_body.plot(kind='bar', color='lightblue')
plt.title('Top 10 najlepiej sprzedających się typów nadwozia')
plt.xlabel('Typ nadwozia')
plt.ylabel('Liczba sprzedanych pojazdów')
plt.savefig('typ_nadwozia.png', dpi=300, facecolor='white')
plt.show()
# Out:
# Top 10 najlepiej sprzedających się typów nadwozia:
# body
# Sedan          199437
# SUV            119292
# sedan           41906
# suv             24552
# Hatchback       21380
# Minivan         21363
# Coupe           14602
# Wagon           13630
# Crew Cab        13280
# Convertible      8652
# Name: sellingprice, dtype: int64

# %% [markdown]
#  Sedan jest zdecydowanie najpopularniejszym typem nadwozia, z liczbą sprzedanych egzemplarzy wyraźnie przewyższającą inne typy. SUV zajmuje drugie miejsce, co świadczy o rosnącej popularności pojazdów tego segmentu. Inne typy nadwozia, takie jak hatchback czy minivan, również znajdują się w czołówce, ale z mniejszą liczbą sprzedanych egzemplarzy.

# %%
sales_by_color = df.groupby('color')['sellingprice'].count().sort_values(ascending=False).head(10)
print("Top 10 kolorów z największą liczbą sprzedanych pojazdów:")
print(sales_by_color)

# Wizualizacja
plt.figure(figsize=(12, 6))
sales_by_color.plot(kind='bar', color='salmon')
plt.title('Top 10 kolorów z największą liczbą sprzedanych pojazdów')
plt.xlabel('Kolor')
plt.ylabel('Liczba sprzedanych pojazdów')
plt.savefig('top_kolor_sprzedaz.png', dpi=300, facecolor='white')
plt.show()
# Out:
# Top 10 kolorów z największą liczbą sprzedanych pojazdów:
# color
# black     110970
# white     106673
# silver     83389
# gray       82857
# blue       51139
# red        43569
# —          24685
# green      11382
# gold       11342
# beige       9222
# Name: sellingprice, dtype: int64

# %% [markdown]
# Kolory takie jak czarny, biały i srebrny są najczęściej wybierane przez nabywców, co nie jest zaskoczeniem, biorąc pod uwagę ich popularność na rynku. Są to kolory neutralne, które zazwyczaj lepiej utrzymują swoją wartość na rynku wtórnym. Inne kolory, takie jak niebieski i czerwony, również znajdują się w top 10, ale w mniejszych ilościach.

# %% [markdown]
# ### Wstępna wizualizacja danych po usunięciu wierszy z brakującymi wartościami za pomocą metody dropna()

# %%
df_clean = df.dropna()

missing_values2 = df_clean.isnull().sum()

print(missing_values2)

missing_percentage2 = (df_clean.isnull().sum() / len(df_clean)) * 100
print(missing_percentage2)

df_clean.info()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64
# year            0.0
# make            0.0
# model           0.0
# trim            0.0
# body            0.0
# transmission    0.0
# vin             0.0
# state           0.0
# condition       0.0
# odometer        0.0
# color           0.0
# interior        0.0
# seller          0.0
# mmr             0.0
# sellingprice    0.0
# saledate        0.0
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 472336 entries, 0 to 558810
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          472336 non-null  int64
#  1   make          472336 non-null  object
#  2   model         472336 non-null  object
#  3   trim          472336 non-null  object
#  4   body          472336 non-null  object
#  5   transmission  472336 non-null  object
#  6   vin           472336 non-null  object
#  7   state         472336 non-null  object
#  8   condition     472336 non-null  float64
#  9   odometer      472336 non-null  float64
#  10  color         472336 non-null  object
#  11  interior      472336 non-null  object
#  12  seller        472336 non-null  object
#  13  mmr           472336 non-null  int64
#  14  sellingprice  472336 non-null  int64
#  15  saledate      472336 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 61.3+ MB

# %%
nums_without_na_values = df_clean.select_dtypes(exclude=['object'])
nums_without_na_values.describe(percentiles=(.25, .75, .90, .95, .98))
# Out:
#                 year      condition       odometer            mmr  \
# count  472336.000000  472336.000000  472336.000000  472336.000000
# mean     2010.211045       3.426576   66701.070003   13836.999773
# std         3.822131       0.943659   51939.183430    9532.131753
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000       2.700000   28137.000000    7425.000000
# 50%      2012.000000       3.600000   51084.000000   12300.000000
# 75%      2013.000000       4.200000   96589.000000   18300.000000
# 90%      2014.000000       4.600000  139006.500000   25400.000000
# 95%      2014.000000       4.800000  165554.250000   30500.000000
# 98%      2014.000000       4.900000  197697.300000   38100.000000
# max      2015.000000       5.000000  999999.000000  182000.000000
#
#         sellingprice
# count  472336.000000
# mean    13690.403670
# std      9612.962279
# min         1.000000
# 25%      7200.000000
# 50%     12200.000000
# 75%     18200.000000
# 90%     25400.000000
# 95%     30500.000000
# 98%     38200.000000
# max    230000.000000

# %%
nums_without_na_values.hist(bins=30, figsize=(15, 10), layout=(3, 2))
plt.tight_layout()
plt.savefig('histogramy_bez_nan.png', dpi=300, facecolor='white')
plt.show()

# %%
non_nums_without_na_values = df_clean.select_dtypes(include=['object'])
non_nums_without_na_values.describe()
# Out:
#           make   model    trim    body transmission                vin  \
# count   472336  472336  472336  472336       472336             472336
# unique      53     768    1507      85            2             465779
# top       Ford  Altima    Base   Sedan    automatic  5uxfe43579l274932
# freq     81014   16346   48781  174654       455974                  4
#
#          state   color interior                         seller  \
# count   472336  472336   472336                         472336
# unique      34      20       17                          11927
# top         fl   black    black  ford motor credit company,llc
# freq     75243   93245   209870                          17756
#
#                                        saledate
# count                                    472336
# unique                                     3609
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5004

# %%
show_boxplot(nums_without_na_values, 'Boxploty dla zmiennych numerycznych bez brakujących danych')

# %%
num_columns = ['sellingprice', 'odometer', 'mmr', 'year', 'condition']

# Usuwanie wartości odstających dla każdej zmiennej numerycznej
nums_without_na_values_clean = nums_without_na_values.copy()
for column in num_columns:
    nums_without_na_values_clean = remove_outliers(nums_without_na_values_clean, column)

# %%
show_separate_boxplot(nums_without_na_values,nums_without_na_values_clean,num_columns)

# %%
sns.pairplot(nums_without_na_values)
plt.suptitle('Pairplot dla wybranych zmiennych numerycznych', y=1.02)
plt.show()

# %% [markdown]
# ## Pomysły na zmiany cech
# - obliczenie ile lat miał samochód w momencie sprzedaży
# - wyciągnięcie miesięcy z saledate - sprawdzenie w którcyh miesiącach najwięcej samochodów się sprzedaje (może będzie to pomocne w predukcji)
# - z saledate można wyciągnąc dni tygodnia - też mogą mieć wpływ na ilość sprzedanych samochodów i może na cene
# - z numeru vim wyciagnac dane (kraj produkcji, typ pojazdu - jesli to cos innego niz body/trim/model?:
# from vininfo import Vin
# - zmiana typu skrzyni biegów ze stringa na 0 i 1 przy czym manualna to 0, a automatyczna to 1
# -  porównanie, czy dane zawarte w numerze VIN zgadzają się w tych podanych w pozostałych kolumnach
# - sprawdzenie czy informacje zawarte w numerze VIN różnią się w zależności od producenta
#
# #Przykładowy numer VIN
# vin_number = "1HGCM82633A123456"
#
# #Dekodowanie numeru VIN
# vin = Vin(vin_number)
#
# #Wyświetlenie informacji
# print(f"Producent: {vin.make}")
# print(f"Model: {vin.model}")
# print(f"Rok produkcji: {vin.year}")
# print(f"Kraj produkcji: {vin.country}")
# print(f"Typ pojazdu: {vin.vehicle_type}")
# - oryginalny vim usunac - w tej formie jest unikalny dla kazdego pojazdu więc nie a sensu go trzymać  - jedynie jako ciekawostke, np jakiś samochód był na aukcji więcej niż jeden raz

# %% [markdown]
# ## zmiany cech

# %%
df['saledate'] = pd.to_datetime(df['saledate'], errors='coerce', infer_datetime_format=True, utc=True)

# %%
df['car_age'] = df['saledate'].dt.year - df['year']
df['sale_year'] = df['saledate'].dt.year
df['sale_month'] = df['saledate'].dt.month
df['sale_hour'] = df['saledate'].dt.hour
df['sale_minute'] = df['saledate'].dt.minute

# %%
sales_by_month = df['sale_month'].value_counts().sort_index()
print("Sprzedaż według miesiąca:")
print(sales_by_month)
# Out:
# Sprzedaż według miesiąca:
# 1     140815
# 2     163054
# 3      46342
# 4       1438
# 5      53102
# 6      99283
# 7       1257
# 12     53520
# Name: sale_month, dtype: int64

# %%
df['sale_weekday'] = df['saledate'].dt.weekday
sales_by_weekday = df['sale_weekday'].value_counts().sort_index()
print("Sprzedaż według dnia tygodnia:")
print(sales_by_weekday)
# Out:
# Sprzedaż według dnia tygodnia:
# 0    131299
# 1    180158
# 2    146366
# 3     77892
# 4     11228
# 6     11868
# Name: sale_weekday, dtype: int64

# %%
def extract_vin_info(vin_number):
    try:
        vin = Vin(vin_number)
        vin_info = {
            'vin_country': vin.country if hasattr(vin, 'country') else None,
        }
        return vin_info
    except AttributeError as e:
        print(f"Błąd podczas przetwarzania VIN: {vin_number} - {e}")
        return {'vin_country': None, 'vin_vehicle_type': None}

# %%
vin_info = df['vin'].apply(extract_vin_info)

df['vin_country'] = vin_info.apply(lambda x: x['vin_country'])

# %%
df.drop(columns=['vin'], inplace=True)

# %%
df.drop(columns=['saledate'], inplace=True)

# %%
df.head(5)
# Out:
#    year   make                model        trim   body transmission state  \
# 0  2015    Kia              Sorento          LX    SUV    automatic    ca
# 1  2015    Kia              Sorento          LX    SUV    automatic    ca
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic    ca
# 3  2015  Volvo                  S60          T5  Sedan    automatic    ca
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic    ca
#
#    condition  odometer  color  ...                                  seller  \
# 0        5.0   16639.0  white  ...                 kia motors america, inc
# 1        5.0    9393.0  white  ...                 kia motors america, inc
# 2        4.5    1331.0   gray  ...  financial services remarketing (lease)
# 3        4.1   14282.0  white  ...                 volvo na rep/world omni
# 4        4.3    2641.0   gray  ...  financial services remarketing (lease)
#
#      mmr  sellingprice  car_age  sale_year  sale_month  sale_hour  \
# 0  20500         21500       -1       2014          12          4
# 1  20800         21500       -1       2014          12          4
# 2  31900         30000        1       2015           1         20
# 3  27500         27750        0       2015           1         20
# 4  66000         67000        0       2014          12          4
#
#    sale_minute  sale_weekday    vin_country
# 0           30             1  United States
# 1           30             1  United States
# 2           30             2        Germany
# 3           30             2         Sweden
# 4           30             3        Germany
#
# [5 rows x 21 columns]

# %% [markdown]
# ## wartości odstające

# %%
nums_name = ["year", "condition", "odometer", "mmr", "sellingprice"]
outlier_percentages = {}

for column in nums_name:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    
    outlier_percentage = len(outliers) / len(df) * 100
    outlier_percentages[column] = outlier_percentage

print(outlier_percentages)
# Out:
# {'year': 0.7195635017921981, 'condition': 0.0, 'odometer': 1.8566205747560447, 'mmr': 2.9195917761103485, 'sellingprice': 2.9265708799576244}

# %% [markdown]
# Wartości odstające zostaną usunietę - ich ilość nie przekracza 10% zbioru

# %%
df_no_outliers = df.copy()

for column in nums_name:
    Q1 = df_no_outliers[column].quantile(0.25)
    Q3 = df_no_outliers[column].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df_no_outliers = df_no_outliers[(df_no_outliers[column] >= lower_bound) & (df_no_outliers[column] <= upper_bound)]

# %%
(df.shape[0]-df_no_outliers.shape[0])/df.shape[0]
# Out:
# 0.08336986924022613

# %% [markdown]
# usunięto około 8.3% danych

# %% [markdown]
# ## odpowiednie przekształcenie danych typu string na wartości liczbowe

# %%
category = ['make', 'model', 'trim', 'body', "transmission", 'state', 'color', 'interior', 'seller', 'vin_country']

# %%
category_mappings = {}
for c in category:
    df_no_outliers[c] = df_no_outliers[c].astype('category')
    category_mappings[c] = dict(enumerate(df_no_outliers[c].cat.categories))
    df_no_outliers[c] = df_no_outliers[c].cat.codes
    
for col, mapping in category_mappings.items():
    print(f"Mapowanie dla kolumny '{col}':")
    print(mapping)
# Out:
# Mapowanie dla kolumny 'make':
# {0: 'Acura', 1: 'Audi', 2: 'BMW', 3: 'Buick', 4: 'Cadillac', 5: 'Chevrolet', 6: 'Chrysler', 7: 'Daewoo', 8: 'Dodge', 9: 'FIAT', 10: 'Ford', 11: 'GMC', 12: 'HUMMER', 13: 'Honda', 14: 'Hyundai', 15: 'Infiniti', 16: 'Isuzu', 17: 'Jaguar', 18: 'Jeep', 19: 'Kia', 20: 'Land Rover', 21: 'Lexus', 22: 'Lincoln', 23: 'MINI', 24: 'Maserati', 25: 'Mazda', 26: 'Mercedes-Benz', 27: 'Mercury', 28: 'Mitsubishi', 29: 'Nissan', 30: 'Oldsmobile', 31: 'Plymouth', 32: 'Pontiac', 33: 'Porsche', 34: 'Ram', 35: 'Saab', 36: 'Saturn', 37: 'Scion', 38: 'Subaru', 39: 'Suzuki', 40: 'Toyota', 41: 'Volkswagen', 42: 'Volvo', 43: 'acura', 44: 'audi', 45: 'bmw', 46: 'buick', 47: 'cadillac', 48: 'chevrolet', 49: 'chrysler', 50: 'dodge', 51: 'dot', 52: 'ford', 53: 'ford tk', 54: 'ford truck', 55: 'gmc', 56: 'gmc truck', 57: 'honda', 58: 'hyundai', 59: 'jeep', 60: 'kia', 61: 'land rover', 62: 'landrover', 63: 'lexus', 64: 'lincoln', 65: 'maserati', 66: 'mazda', 67: 'mercedes', 68: 'mercedes-b', 69: 'mercury', 70: 'mitsubishi', 71: 'nissan', 72: 'oldsmobile', 73: 'plymouth', 74: 'pontiac', 75: 'porsche', 76: 'smart', 77: 'subaru', 78: 'suzuki', 79: 'toyota', 80: 'volkswagen', 81: 'vw'}
# Mapowanie dla kolumny 'model':
# {0: '1 Series', 1: '1500', 2: '2 Series', 3: '200', 4: '200SX', 5: '2500', 6: '3', 7: '3 Series', 8: '3 Series Gran Turismo', 9: '300', 10: '3000GT', 11: '300M', 12: '323i', 13: '328i', 14: '350', 15: '3500', 16: '350Z', 17: '350z', 18: '370Z', 19: '4 Series', 20: '42c', 21: '4Runner', 22: '5 Series', 23: '5 Series Gran Turismo', 24: '500', 25: '500L', 26: '500e', 27: '6', 28: '6 Series', 29: '6 Series Gran Coupe', 30: '626', 31: '7', 32: '7 Series', 33: '750i', 34: '750li', 35: '750lxi', 36: '9-2X', 37: '9-3', 38: '9-5', 39: '9-7X', 40: '911', 41: 'A3', 42: 'A4', 43: 'A5', 44: 'A6', 45: 'A7', 46: 'A8', 47: 'ATS', 48: 'Acadia', 49: 'Accent', 50: 'Accord', 51: 'Accord Crosstour', 52: 'Accord Hybrid', 53: 'Achieva', 54: 'ActiveHybrid 5', 55: 'ActiveHybrid 7', 56: 'ActiveHybrid X6', 57: 'Aerio', 58: 'Alero', 59: 'Altima', 60: 'Altima Hybrid', 61: 'Amanti', 62: 'Amigo', 63: 'Armada', 64: 'Ascender', 65: 'Aspen', 66: 'Astra', 67: 'Astro', 68: 'Astro Cargo', 69: 'Aura', 70: 'Aura Hybrid', 71: 'Aurora', 72: 'Avalanche', 73: 'Avalon', 74: 'Avalon Hybrid', 75: 'Avenger', 76: 'Aveo', 77: 'Aviator', 78: 'Axiom', 79: 'Azera', 80: 'Aztek', 81: 'B-Class Electric Drive', 82: 'B-Series', 83: 'B-Series Pickup', 84: 'B-Series Truck', 85: 'B9 Tribeca', 86: 'BRZ', 87: 'Baja', 88: 'Beetle', 89: 'Beetle Convertible', 90: 'Black Diamond Avalanche', 91: 'Blackwood', 92: 'Blazer', 93: 'Bonneville', 94: 'Borrego', 95: 'Boxster', 96: 'Bravada', 97: 'C-Class', 98: 'C-Max Energi', 99: 'C-Max Hybrid', 100: 'C/K 1500 Series', 101: 'C/K 3500 Series', 102: 'C/V Cargo Van', 103: 'C/V Tradesman', 104: 'C30', 105: 'C70', 106: 'CC', 107: 'CL', 108: 'CL-Class', 109: 'CLA-Class', 110: 'CLK-Class', 111: 'CLS-Class', 112: 'CR-V', 113: 'CR-Z', 114: 'CT 200h', 115: 'CTS', 116: 'CTS Coupe', 117: 'CTS Wagon', 118: 'CTS-V', 119: 'CTS-V Coupe', 120: 'CV Tradesman', 121: 'CX-5', 122: 'CX-7', 123: 'CX-9', 124: 'Cabrio', 125: 'Cadenza', 126: 'Caliber', 127: 'Camaro', 128: 'Camry', 129: 'Camry Hybrid', 130: 'Camry Solara', 131: 'Canyon', 132: 'Captiva Sport', 133: 'Caravan', 134: 'Catera', 135: 'Cavalier', 136: 'Cayenne', 137: 'Cayman', 138: 'Cayman S', 139: 'Celica', 140: 'Century', 141: 'Challenger', 142: 'Charger', 143: 'Cherokee', 144: 'Cirrus', 145: 'Civic', 146: 'Classic', 147: 'Cobalt', 148: 'Colorado', 149: 'Commander', 150: 'Compass', 151: 'Concorde', 152: 'Continental', 153: 'Contour', 154: 'Cooper', 155: 'Cooper Clubman', 156: 'Cooper Countryman', 157: 'Cooper Coupe', 158: 'Cooper Paceman', 159: 'Cooper Roadster', 160: 'Corolla', 161: 'Corvette', 162: 'Cougar', 163: 'Coupe', 164: 'Crossfire', 165: 'Crosstour', 166: 'Crown Victoria', 167: 'Cruze', 168: 'Cube', 169: 'Cutlass', 170: 'DTS', 171: 'Dakota', 172: 'Dart', 173: 'DeVille', 174: 'Diamante', 175: 'Discovery', 176: 'Discovery Series II', 177: 'Durango', 178: 'E-150', 179: 'E-250', 180: 'E-350', 181: 'E-Class', 182: 'E-Series Van', 183: 'E-Series Wagon', 184: 'ECHO', 185: 'ES 300', 186: 'ES 300h', 187: 'ES 330', 188: 'ES 350', 189: 'EX', 190: 'EX35', 191: 'Eclipse', 192: 'Eclipse Spyder', 193: 'Econoline Cargo', 194: 'Econoline Wagon', 195: 'Edge', 196: 'Eighty-Eight', 197: 'Elantra', 198: 'Elantra Coupe', 199: 'Elantra GT', 200: 'Elantra Touring', 201: 'Eldorado', 202: 'Element', 203: 'Enclave', 204: 'Encore', 205: 'Endeavor', 206: 'Entourage', 207: 'Envoy', 208: 'Envoy XL', 209: 'Envoy XUV', 210: 'Eos', 211: 'Equator', 212: 'Equinox', 213: 'Equus', 214: 'Escalade', 215: 'Escalade ESV', 216: 'Escalade EXT', 217: 'Escalade Hybrid', 218: 'Escape', 219: 'Escape Hybrid', 220: 'Escort', 221: 'Esteem', 222: 'EuroVan', 223: 'Excursion', 224: 'Expedition', 225: 'Expedition EL', 226: 'Explorer', 227: 'Explorer Sport', 228: 'Explorer Sport Trac', 229: 'Express', 230: 'Express Cargo', 231: 'F-150', 232: 'F-150 Heritage', 233: 'F-150 SVT Lightning', 234: 'F-250 Super Duty', 235: 'F-350 Super Duty', 236: 'F-450 Super Duty', 237: 'FJ Cruiser', 238: 'FR-S', 239: 'FX', 240: 'FX35', 241: 'FX45', 242: 'FX50', 243: 'Fiesta', 244:  ...
# Mapowanie dla kolumny 'trim':
# {0: '!', 1: '& coun fwd', 2: '& coun fwd limited', 3: '& coun fwd lx', 4: '& country lx', 5: '(1999.5) XE', 6: '+', 7: '1', 8: '1.6', 9: '1.6 Base', 10: '1.6 S', 11: '1.6 S Plus', 12: '1.6 SL', 13: '1.6 SV', 14: '1.8', 15: '1.8 Base', 16: '1.8 Krom', 17: '1.8 S', 18: '1.8 S Krom Edition', 19: '1.8 SL', 20: '1.8 TFSI Premium', 21: '1.8 TFSI Premium Plus', 22: '1.8T', 23: '1.8T Avant quattro', 24: '1.8T Classic', 25: '1.8T quattro', 26: '1.9', 27: '128i', 28: '128i SULEV', 29: '135i', 30: '135is', 31: '150 Low Roof', 32: '1500', 33: '1500 4x2 cr sle', 34: '1500 4x2 cr sle1', 35: '1500 4x4 cr slt', 36: '1500 4x4 ex sle', 37: '1500 4x4 v8 slt', 38: '1500 High Roof', 39: '1500 LS', 40: '1500 LT', 41: '1500 LT1', 42: '1500 LTZ', 43: '1500 Low Roof', 44: '1500 Maxi', 45: '1500 S', 46: '1500 SLE', 47: '1500 SLT', 48: '1500 SV', 49: '1500 awd cr denali', 50: '1500 lramie slt', 51: '180hp', 52: '180hp quattro', 53: '1LS Fleet', 54: '1LT', 55: '1LT Fleet', 56: '1SS', 57: '2', 58: '2.0', 59: '2.0 S', 60: '2.0 SL', 61: '2.0 SR', 62: '2.0 TDI Premium', 63: '2.0 TDI Premium Plus', 64: '2.0 TFSI Premium Plus quattro', 65: '2.0 TFSI Premium quattro', 66: '2.0 TFSI Prestige quattro', 67: '2.0L TDI', 68: '2.0T', 69: '2.0T Avant Premium quattro', 70: '2.0T Avant quattro', 71: '2.0T PZEV', 72: '2.0T PZEV Premium', 73: '2.0T Premium', 74: '2.0T Premium Avant quattro', 75: '2.0T Premium Plus', 76: '2.0T Premium Plus quattro', 77: '2.0T Premium quattro', 78: '2.0T Premium quattro ', 79: '2.0T Prestige', 80: '2.0T Prestige quattro', 81: '2.0T R-Spec', 82: '2.0T SportCombi', 83: '2.0T Turbo ', 84: '2.0T Turbo PZEV', 85: '2.0T White Turbo Launch Edition', 86: '2.0T White Turbo Launch Edition PZEV', 87: '2.0T quattro', 88: '2.0XT Premium', 89: '2.0XT Touring', 90: '2.0i', 91: '2.0i Limited PZEV', 92: '2.0i PZEV', 93: '2.0i Premium PZEV', 94: '2.0i Sport Limited PZEV', 95: '2.0i Sport Premium PZEV', 96: '2.3', 97: '2.3 Premium', 98: '2.3t', 99: '2.4', 100: '2.4M', 101: '2.4T', 102: '2.4i', 103: '2.5', 104: '2.5 GT', 105: '2.5 GT Limited', 106: '2.5 I', 107: '2.5 I Limited', 108: '2.5 PZEV', 109: '2.5 RS', 110: '2.5 S', 111: '2.5 SL', 112: '2.5 SV', 113: '2.5 TS', 114: '2.5 X', 115: '2.5 X L.L.Bean Edition', 116: '2.5 X Premium Package', 117: '2.5 XT', 118: '2.5 XT Limited', 119: '2.5 i', 120: '2.5GT Limited', 121: '2.5I', 122: '2.5I Limited', 123: '2.5L', 124: '2.5L ', 125: '2.5L Blush Edition', 126: '2.5L Blush Edition PZEV', 127: '2.5L Final Edition', 128: '2.5L Final Edition PZEV', 129: '2.5L PZEV', 130: '2.5L Red Rock Edition', 131: '2.5L Red Rock Edition PZEV', 132: '2.5T', 133: '2.5T SE', 134: '2.5X', 135: '2.5X Limited', 136: '2.5X Limited PZEV', 137: '2.5X PZEV', 138: '2.5X Premium', 139: '2.5X Premium PZEV', 140: '2.5X Touring', 141: '2.5X Touring PZEV', 142: '2.5XT', 143: '2.5XT Limited', 144: '2.5XT Premium', 145: '2.5XT Touring', 146: '2.5i', 147: '2.5i Limited', 148: '2.5i Limited PZEV', 149: '2.5i PZEV', 150: '2.5i Premium', 151: '2.5i Premium PZEV', 152: '2.5i Special Edition', 153: '2.5i Sport', 154: '2.5i Sport PZEV', 155: '2.5i Touring PZEV', 156: '2.5l', 157: '2.7T S-Line quattro', 158: '2.7T quattro', 159: '2.8', 160: '2.8 Avant quattro', 161: '2.8 quattro', 162: '2.9', 163: '20th Anniversary Edition', 164: '225hp quattro', 165: '228i', 166: '25 4x4 cr sle', 167: '250 High Roof', 168: '250 Low Roof', 169: '250 Medium Roof', 170: '2500', 171: '2500 118 WB', 172: '2500 140 WB', 173: '2500 144 WB', 174: '2500 144 WB Cargo', 175: '2500 144 WB Crew', 176: '2500 144 WB Passenger', 177: '2500 170 WB', 178: '2500 170 WB Cargo', 179: '2500 170 WB Passenger', 180: '2500 High Roof', 181: '2500 High Roof 140 WB', 182: '2500 High Roof 158 WB', 183: '2500 LS', 184: '2500 LT', 185: '2500 S', 186: '2500 SH Ceiling 140 WB', 187: '2500 SLE', 188: '2500 SV', 189: '2500k lt', 190: '250hp quattro', 191: '2LS Fleet', 192: '2LT', 193: '2SS', 194: '2wd ext base', 195: '2wd ext ls', 196: '3', 197: '3.0', 198: '3.0 Avant quattro', 199: '3.0 Premium', 200: '3.0  ...
# Mapowanie dla kolumny 'body':
# {0: 'Access Cab', 1: 'Beetle Convertible', 2: 'CTS Coupe', 3: 'CTS Wagon', 4: 'CTS-V Coupe', 5: 'Cab Plus', 6: 'Cab Plus 4', 7: 'Club Cab', 8: 'Convertible', 9: 'Coupe', 10: 'Crew Cab', 11: 'CrewMax Cab', 12: 'Double Cab', 13: 'E-Series Van', 14: 'Elantra Coupe', 15: 'Extended Cab', 16: 'G Convertible', 17: 'G Coupe', 18: 'G Sedan', 19: 'G37 Convertible', 20: 'G37 Coupe', 21: 'Genesis Coupe', 22: 'Hatchback', 23: 'King Cab', 24: 'Koup', 25: 'Mega Cab', 26: 'Minivan', 27: 'Promaster Cargo Van', 28: 'Q60 Convertible', 29: 'Q60 Coupe', 30: 'Quad Cab', 31: 'Ram Van', 32: 'Regular Cab', 33: 'SUV', 34: 'Sedan', 35: 'SuperCab', 36: 'SuperCrew', 37: 'TSX Sport Wagon', 38: 'Transit Van', 39: 'Van', 40: 'Wagon', 41: 'Xtracab', 42: 'access cab', 43: 'beetle convertible', 44: 'cab plus 4', 45: 'club cab', 46: 'convertible', 47: 'coupe', 48: 'crew cab', 49: 'crewmax cab', 50: 'cts coupe', 51: 'cts wagon', 52: 'double cab', 53: 'e-series van', 54: 'elantra coupe', 55: 'extended cab', 56: 'g convertible', 57: 'g coupe', 58: 'g sedan', 59: 'g37 convertible', 60: 'g37 coupe', 61: 'genesis coupe', 62: 'hatchback', 63: 'king cab', 64: 'koup', 65: 'mega cab', 66: 'minivan', 67: 'promaster cargo van', 68: 'q60 coupe', 69: 'quad cab', 70: 'regular cab', 71: 'regular-cab', 72: 'sedan', 73: 'supercab', 74: 'supercrew', 75: 'suv', 76: 'transit van', 77: 'tsx sport wagon', 78: 'van', 79: 'wagon', 80: 'xtracab'}
# Mapowanie dla kolumny 'transmission':
# {0: 'automatic', 1: 'manual'}
# Mapowanie dla kolumny 'state':
# {0: 'ab', 1: 'al', 2: 'az', 3: 'ca', 4: 'co', 5: 'fl', 6: 'ga', 7: 'hi', 8: 'il', 9: 'in', 10: 'la', 11: 'ma', 12: 'md', 13: 'mi', 14: 'mn', 15: 'mo', 16: 'ms', 17: 'nc', 18: 'ne', 19: 'nj', 20: 'nm', 21: 'ns', 22: 'nv', 23: 'ny', 24: 'oh', 25: 'ok', 26: 'on', 27: 'or', 28: 'pa', 29: 'pr', 30: 'qc', 31: 'sc', 32: 'tn', 33: 'tx', 34: 'ut', 35: 'va', 36: 'wa', 37: 'wi'}
# Mapowanie dla kolumny 'color':
# {0: 'beige', 1: 'black', 2: 'blue', 3: 'brown', 4: 'burgundy', 5: 'charcoal', 6: 'gold', 7: 'gray', 8: 'green', 9: 'lime', 10: 'off-white', 11: 'orange', 12: 'pink', 13: 'purple', 14: 'red', 15: 'silver', 16: 'turquoise', 17: 'white', 18: 'yellow', 19: '—'}
# Mapowanie dla kolumny 'interior':
# {0: 'beige', 1: 'black', 2: 'blue', 3: 'brown', 4: 'burgundy', 5: 'gold', 6: 'gray', 7: 'green', 8: 'off-white', 9: 'orange', 10: 'purple', 11: 'red', 12: 'silver', 13: 'tan', 14: 'white', 15: 'yellow', 16: '—'}
# Mapowanie dla kolumny 'seller':
# {0: '1 cochran of monroeville', 1: '101motors', 2: '1360250 alberta ltd', 3: '1360250 alberta ltd.', 4: '138 auto inc', 5: '1428879 alberta ltd', 6: '143 auto sales inc', 7: '1479582 alberta ltd.', 8: '1491081 alberta inc.', 9: '1582529 alberta ltd', 10: '159191 canada inc', 11: '1764175 alberta ltd', 12: '1770144 alberta ltd', 13: '1814099 alberta ltd', 14: '1solution auto network llc', 15: '1st advantage fcu', 16: '1st canadian auto sales & service', 17: '1st choice auto sales', 18: '1st choice automotive corp', 19: '1st choice credit union', 20: '1st choice money center', 21: '1st class auto', 22: '1st commercial', 23: '1st financial fcu', 24: '1st gear auto inc', 25: '1st liberty fcu', 26: '1st liberty federal credit union', 27: '1st mid america credit union', 28: '1st national bank of scotia', 29: '1st source bank', 30: '2 fran-nick auto sales llc', 31: '2020 motors', 32: '223 auto sales llc', 33: '22nd street motors inc', 34: '231 car sales,inc.', 35: '2626 5660 quebec inc', 36: '2842 2988 quebec inc', 37: '2970 7528 quebec inc', 38: '2nd chance auto sales', 39: '3 in one auto sales inc', 40: '3 line motors llc', 41: '3117839 canada inc', 42: '3242878 nova scotia company', 43: '355 toyota', 44: '360 motors inc', 45: '4 below auto sales & service llc', 46: '4 h auto sales llc', 47: '414 car mart', 48: '414 motor cars llc', 49: '46 vans & trucks llc', 50: '460 auto sales', 51: '486236 alberta ltd', 52: '4jg stars auto sales llc', 53: '4x4 auto sales', 54: '5 corners truck & auto inc', 55: '5 star auto', 56: '5 star auto sales', 57: '5 star loans', 58: '5280 motorcars', 59: '611 car connection', 60: '639475 alberta ltd', 61: '66 auto sales', 62: '67 auto sales', 63: '695 auto sales & service', 64: '721740 alberta ltd', 65: '760 auto couture', 66: '778025 alberta ltd', 67: '77th street depot federal credit union', 68: '800 loan mart', 69: '800cash247', 70: '84th street motors inc', 71: '888 motors', 72: '9076 4754 quebec inc', 73: '91 automotive west', 74: '9109 4672 quebec inc', 75: '9128 8654 quebec inc', 76: '9179 4131 quebec inc', 77: '9195 9023 quebec inc', 78: '9207 5787 quebec inc', 79: '9209 0851 quebec inc', 80: '9219 6484 quebec inc', 81: '924 auto corp', 82: '9250 3002 quebec inc', 83: '9th avenue automotive', 84: 'a & a auto and truck center inc', 85: 'a & a auto sales', 86: 'a & a luxury auto sales inc', 87: 'a & a quality services inc', 88: 'a & b auto inc', 89: 'a & b auto sales', 90: 'a & c motors auto sales inc', 91: 'a & h import', 92: 'a & j motors inc', 93: 'a & l auto sales llc', 94: 'a & m auto sale', 95: 'a & m auto sales llc', 96: 'a & m auto wholesalers llc', 97: 'a & m finance', 98: 'a & m used auto sales inc', 99: 'a & n auto group inc', 100: 'a & n auto sales inc', 101: 'a & p wholesale auto dealer', 102: 'a & r automobile sales, llc', 103: 'a & s auto and truck sales llc', 104: 'a & t auto sales llc', 105: 'a & z auto sales', 106: 'a 1 motors', 107: 'a 2 z car sales', 108: 'a a a motors inc', 109: 'a and a auto mart inc', 110: 'a and a ii llc', 111: 'a and a recreation', 112: 'a and d motors llc', 113: 'a and j auto sales', 114: 'a automotive inc auto sales', 115: 'a automotive llc', 116: 'a better way wholesale autos inc', 117: 'a cars one', 118: 'a crivelli buick gmc inc', 119: 'a d autos', 120: 'a ffordable cars', 121: 'a g auto sales', 122: 'a l financial', 123: 'a l financial corporation', 124: 'a line auto wholesale', 125: 'a m auto sales', 126: 'a plus auto outlet', 127: 'a plus auto sales & detailing llc', 128: 'a plus auto sales inc', 129: 'a plus fine cars', 130: 'a plus imports', 131: 'a s auto sales', 132: 'a select of orange inc', 133: 'a to z liquidators inc', 134: 'a town auto brokers', 135: 'a v auto sales llc', 136: 'a&a financial', 137: 'a&c wholesale', 138: 'a&e automotive llc', 139: 'a&m finance', 140: 'a&r motors llc', 141: 'a&r motors, llc', 142: 'a&r service center inc', 143: 'a+ autobrokers inc', 144: 'a+ fcu', 145: 'a+ oxxo', 146: 'a-1 auto', 147: 'a-1 auto group llc', 14 ...
# Mapowanie dla kolumny 'vin_country':
# {0: 'Australia', 1: 'Brazil', 2: 'Canada', 3: 'France', 4: 'Germany', 5: 'Hungary', 6: 'Italy', 7: 'Japan', 8: 'Mexico', 9: 'South Korea', 10: 'Sweden', 11: 'Thailand', 12: 'Turkey', 13: 'United Kingdom', 14: 'United States'}

# %% [markdown]
# ## uzupelnienie danych brakujacych

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# year             0.000000
# make             1.843378
# model            1.860915
# trim             1.906011
# body             2.361263
# transmission    11.695010
# state            0.000000
# condition        2.110553
# odometer         0.016821
# color            0.134035
# interior         0.134035
# seller           0.000000
# mmr              0.000000
# sellingprice     0.000000
# car_age          0.000000
# sale_year        0.000000
# sale_month       0.000000
# sale_hour        0.000000
# sale_minute      0.000000
# sale_weekday     0.000000
# vin_country      0.000000
# dtype: float64

# %% [markdown]
# ### uzupełnienie średnią danych numerycznych, kategorycznych modą

# %%
df_filled_mean = df_no_outliers.copy().replace(-1, np.nan)

for column in category:
    df_filled_mean[column].fillna(df_filled_mean[column].mode()[0], inplace=True)

for column in df_filled_mean.columns:
    df_filled_mean[column].fillna(df_filled_mean[column].mean(), inplace=True)

# %%
(df_filled_mean.isnull().sum() / len(df)) * 100
# Out:
# year            0.0
# make            0.0
# model           0.0
# trim            0.0
# body            0.0
# transmission    0.0
# state           0.0
# condition       0.0
# odometer        0.0
# color           0.0
# interior        0.0
# seller          0.0
# mmr             0.0
# sellingprice    0.0
# car_age         0.0
# sale_year       0.0
# sale_month      0.0
# sale_hour       0.0
# sale_minute     0.0
# sale_weekday    0.0
# vin_country     0.0
# dtype: float64

# %%
df_filled_mean.head(3)
# Out:
#    year  make  model   trim  body  transmission  state  condition  odometer  \
# 0  2015  19.0  575.0  874.0  33.0           0.0      3        5.0   16639.0
# 1  2015  19.0  575.0  874.0  33.0           0.0      3        5.0    9393.0
# 2  2014   2.0    7.0  265.0  34.0           0.0      3        4.5    1331.0
#
#    color  ...  seller    mmr  sellingprice   car_age  sale_year  sale_month  \
# 0   17.0  ...    6238  20500         21500  4.668333       2014          12
# 1   17.0  ...    6238  20800         21500  4.668333       2014          12
# 2    7.0  ...    4303  31900         30000  1.000000       2015           1
#
#    sale_hour  sale_minute  sale_weekday  vin_country
# 0          4           30             1           14
# 1          4           30             1           14
# 2         20           30             2            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ### uzupełnienie medianą danych numerycznych, kategorycznych modą

# %%
df_filled_median = df_no_outliers.copy().replace(-1, np.nan)

for column in category:
    df_filled_median[column].fillna(df_filled_median[column].mode()[0], inplace=True)

for column in df_filled_median.columns:
    df_filled_median[column].fillna(df_filled_median[column].median(), inplace=True)

# %%
(df_filled_median.isnull().sum() / len(df)) * 100
# Out:
# year            0.0
# make            0.0
# model           0.0
# trim            0.0
# body            0.0
# transmission    0.0
# state           0.0
# condition       0.0
# odometer        0.0
# color           0.0
# interior        0.0
# seller          0.0
# mmr             0.0
# sellingprice    0.0
# car_age         0.0
# sale_year       0.0
# sale_month      0.0
# sale_hour       0.0
# sale_minute     0.0
# sale_weekday    0.0
# vin_country     0.0
# dtype: float64

# %%
df_filled_median.head(3)
# Out:
#    year  make  model   trim  body  transmission  state  condition  odometer  \
# 0  2015  19.0  575.0  874.0  33.0           0.0      3        5.0   16639.0
# 1  2015  19.0  575.0  874.0  33.0           0.0      3        5.0    9393.0
# 2  2014   2.0    7.0  265.0  34.0           0.0      3        4.5    1331.0
#
#    color  ...  seller    mmr  sellingprice  car_age  sale_year  sale_month  \
# 0   17.0  ...    6238  20500         21500      3.0       2014          12
# 1   17.0  ...    6238  20800         21500      3.0       2014          12
# 2    7.0  ...    4303  31900         30000      1.0       2015           1
#
#    sale_hour  sale_minute  sale_weekday  vin_country
# 0          4           30             1           14
# 1          4           30             1           14
# 2         20           30             2            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ### uzupelnienie trudną metodą - kNN

# %%
from sklearn.impute import KNNImputer

# %%
df_knn = df_no_outliers.copy()
print(df_knn.dtypes)
# Out:
# year              int64
# make               int8
# model             int16
# trim              int16
# body               int8
# transmission       int8
# state              int8
# condition       float64
# odometer        float64
# color              int8
# interior           int8
# seller            int16
# mmr               int64
# sellingprice      int64
# car_age           int64
# sale_year         int64
# sale_month        int64
# sale_hour         int64
# sale_minute       int64
# sale_weekday      int64
# vin_country        int8
# dtype: object

# %%
knn_imputer = KNNImputer(n_neighbors=3)
df_imputed_knn = pd.DataFrame(knn_imputer.fit_transform(df_knn), columns=df_knn.columns)

# %%
(df_imputed_knn.isnull().sum() / len(df)) * 100
# Out:
# year            0.0
# make            0.0
# model           0.0
# trim            0.0
# body            0.0
# transmission    0.0
# state           0.0
# condition       0.0
# odometer        0.0
# color           0.0
# interior        0.0
# seller          0.0
# mmr             0.0
# sellingprice    0.0
# car_age         0.0
# sale_year       0.0
# sale_month      0.0
# sale_hour       0.0
# sale_minute     0.0
# sale_weekday    0.0
# vin_country     0.0
# dtype: float64

# %%
df_imputed_knn.head(3)
# Out:
#      year  make  model   trim  body  transmission  state  condition  odometer  \
# 0  2015.0  19.0  575.0  874.0  33.0           0.0    3.0        5.0   16639.0
# 1  2015.0  19.0  575.0  874.0  33.0           0.0    3.0        5.0    9393.0
# 2  2014.0   2.0    7.0  265.0  34.0           0.0    3.0        4.5    1331.0
#
#    color  ...  seller      mmr  sellingprice  car_age  sale_year  sale_month  \
# 0   17.0  ...  6238.0  20500.0       21500.0     -1.0     2014.0        12.0
# 1   17.0  ...  6238.0  20800.0       21500.0     -1.0     2014.0        12.0
# 2    7.0  ...  4303.0  31900.0       30000.0      1.0     2015.0         1.0
#
#    sale_hour  sale_minute  sale_weekday  vin_country
# 0        4.0         30.0           1.0         14.0
# 1        4.0         30.0           1.0         14.0
# 2       20.0         30.0           2.0          4.0
#
# [3 rows x 21 columns]

# %% [markdown]
# ## skalowanie min_max

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns.difference(category)

# %% [markdown]
# ### zbior 1

# %%
df_filled_mean_min_max = df_filled_mean.copy()
df_filled_mean_min_max[num_cols] = scaler.fit_transform(df_filled_mean[num_cols])
df_filled_mean_min_max.head(3)
# Out:
#        year  make  model   trim  body  transmission  state  condition  \
# 0  1.000000  19.0  575.0  874.0  33.0           0.0      3      1.000
# 1  1.000000  19.0  575.0  874.0  33.0           0.0      3      1.000
# 2  0.941176   2.0    7.0  265.0  34.0           0.0      3      0.875
#
#    odometer  color  ...  seller       mmr  sellingprice   car_age  sale_year  \
# 0  0.083411   17.0  ...    6238  0.588785      0.643702  0.274608        0.0
# 1  0.047085   17.0  ...    6238  0.597412      0.643702  0.274608        0.0
# 2  0.006668    7.0  ...    4303  0.916607      0.898201  0.058824        1.0
#
#    sale_month  sale_hour  sale_minute  sale_weekday  vin_country
# 0         1.0   0.173913     0.508475      0.166667           14
# 1         1.0   0.173913     0.508475      0.166667           14
# 2         0.0   0.869565     0.508475      0.333333            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ### zbior 2

# %%
df_filled_median_min_max = df_filled_median.copy()
df_filled_median_min_max[num_cols] = scaler.fit_transform(df_filled_median[num_cols])
df_filled_median_min_max.head(3)
# Out:
#        year  make  model   trim  body  transmission  state  condition  \
# 0  1.000000  19.0  575.0  874.0  33.0           0.0      3      1.000
# 1  1.000000  19.0  575.0  874.0  33.0           0.0      3      1.000
# 2  0.941176   2.0    7.0  265.0  34.0           0.0      3      0.875
#
#    odometer  color  ...  seller       mmr  sellingprice   car_age  sale_year  \
# 0  0.083411   17.0  ...    6238  0.588785      0.643702  0.176471        0.0
# 1  0.047085   17.0  ...    6238  0.597412      0.643702  0.176471        0.0
# 2  0.006668    7.0  ...    4303  0.916607      0.898201  0.058824        1.0
#
#    sale_month  sale_hour  sale_minute  sale_weekday  vin_country
# 0         1.0   0.173913     0.508475      0.166667           14
# 1         1.0   0.173913     0.508475      0.166667           14
# 2         0.0   0.869565     0.508475      0.333333            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ### zbior 3

# %%
df_imputed_knn_min_max = df_knn.copy()
df_imputed_knn_min_max[num_cols] = scaler.fit_transform(df_imputed_knn[num_cols])
df_imputed_knn_min_max.head(3)
# Out:
#        year  make  model  trim  body  transmission  state  condition  \
# 0  1.000000    19    575   874    33             0      3      1.000
# 1  1.000000    19    575   874    33             0      3      1.000
# 2  0.941176     2      7   265    34             0      3      0.875
#
#    odometer  color  ...  seller       mmr  sellingprice   car_age  sale_year  \
# 0  0.083411     17  ...    6238  0.588785      0.643702  0.000000        0.0
# 1  0.047085     17  ...    6238  0.597412      0.643702  0.000000        0.0
# 2  0.006668      7  ...    4303  0.916607      0.898201  0.111111        1.0
#
#    sale_month  sale_hour  sale_minute  sale_weekday  vin_country
# 0         1.0   0.173913     0.508475      0.166667           14
# 1         1.0   0.173913     0.508475      0.166667           14
# 2         0.0   0.869565     0.508475      0.333333            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ## standaryzacja

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# ### zbior 1

# %%
df_filled_mean_standard = df_filled_mean.copy()
df_filled_mean_standard[num_cols] = scaler.fit_transform(df_filled_mean[num_cols])
df_filled_mean_standard.head(3)
# Out:
#        year  make  model   trim  body  transmission  state  condition  \
# 0  1.306868  19.0  575.0  874.0  33.0           0.0      3   1.692720
# 1  1.306868  19.0  575.0  874.0  33.0           0.0      3   1.692720
# 2  1.031353   2.0    7.0  265.0  34.0           0.0      3   1.155341
#
#    odometer  color  ...  seller       mmr  sellingprice  car_age  sale_year  \
# 0 -1.055929   17.0  ...    6238  1.014087      1.159422   0.0000  -3.478698
# 1 -1.214770   17.0  ...    6238  1.054958      1.159422   0.0000  -3.478698
# 2 -1.391498    7.0  ...    4303  2.567210      2.304072  -1.0116   0.287464
#
#    sale_month  sale_hour  sale_minute  sale_weekday  vin_country
# 0    2.770865  -1.934646     0.896025     -0.359347           14
# 1    2.770865  -1.934646     0.896025     -0.359347           14
# 2   -0.864748   0.622579     0.896025      0.449545            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ### zbior 2

# %%
df_filled_median_standard = df_filled_median.copy()
df_filled_median_standard[num_cols] = scaler.fit_transform(df_filled_median[num_cols])
df_filled_median_standard.head(3)
# Out:
#        year  make  model   trim  body  transmission  state  condition  \
# 0  1.306868  19.0  575.0  874.0  33.0           0.0      3   1.692720
# 1  1.306868  19.0  575.0  874.0  33.0           0.0      3   1.692720
# 2  1.031353   2.0    7.0  265.0  34.0           0.0      3   1.155341
#
#    odometer  color  ...  seller       mmr  sellingprice   car_age  sale_year  \
# 0 -1.055929   17.0  ...    6238  1.014087      1.159422 -0.459953  -3.478698
# 1 -1.214770   17.0  ...    6238  1.054958      1.159422 -0.459953  -3.478698
# 2 -1.391498    7.0  ...    4303  2.567210      2.304072 -1.011471   0.287464
#
#    sale_month  sale_hour  sale_minute  sale_weekday  vin_country
# 0    2.770865  -1.934646     0.896025     -0.359347           14
# 1    2.770865  -1.934646     0.896025     -0.359347           14
# 2   -0.864748   0.622579     0.896025      0.449545            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ### zbior 3

# %%
df_imputed_knn_standard = df_knn.copy()
df_imputed_knn_standard[num_cols] = scaler.fit_transform(df_imputed_knn[num_cols])
df_imputed_knn_standard.head(3)
# Out:
#        year  make  model  trim  body  transmission  state  condition  \
# 0  1.306868    19    575   874    33             0      3   1.692720
# 1  1.306868    19    575   874    33             0      3   1.692720
# 2  1.031353     2      7   265    34             0      3   1.155341
#
#    odometer  color  ...  seller       mmr  sellingprice   car_age  sale_year  \
# 0 -1.055929     17  ...    6238  1.014087      1.159422 -1.562345  -3.478698
# 1 -1.214770     17  ...    6238  1.054958      1.159422 -1.562345  -3.478698
# 2 -1.391498      7  ...    4303  2.567210      2.304072 -1.010966   0.287464
#
#    sale_month  sale_hour  sale_minute  sale_weekday  vin_country
# 0    2.770865  -1.934646     0.896025     -0.359347           14
# 1    2.770865  -1.934646     0.896025     -0.359347           14
# 2   -0.864748   0.622579     0.896025      0.449545            4
#
# [3 rows x 21 columns]

# %% [markdown]
# ## zapisanie danych

# %%
dataframes = {
    "mean_min_max": df_filled_mean_min_max,
    "median_min_max": df_filled_median_min_max,
    "knn_min_max": df_imputed_knn_min_max,
    "mean_standard": df_filled_mean_standard,
    "median_standard": df_filled_median_standard,
    "knn_standard": df_imputed_knn_standard
}

for name, df in dataframes.items():
    filename = f"{name}.csv"
    df.to_csv(filename, index=False)
    print(f"Zapisano {filename}")
# Out:
# Zapisano mean_min_max.csv
# Zapisano median_min_max.csv
# Zapisano knn_min_max.csv
# Zapisano mean_standard.csv
# Zapisano median_standard.csv
# Zapisano knn_standard.csv
